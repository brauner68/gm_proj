# %% [markdown]
# # Config + Train

# %%
from src.trainer import DiffusionTrainer
from src.config import get_config
from pathlib import Path

home = Path.home() / 'gm_proj'
data_path = home / 'data/nsynth_data/nsynth-valid'
out_dir = home / 'results/runai_results/01'

# 1. Configuration
config = get_config()
config['output_dir'] = out_dir
config['data_path'] = data_path
config['lr'] = 1e-2
config['max_samples'] = None
config['selected_families'] = ['string']
config['batch_size'] = 32
config['epochs'] = 50
config['save_interval'] = 10
config['cfg_prob'] = 0.1
config['T_target'] = 80

# 2. Run
print("🚀 Starting Training...")
trainer = DiffusionTrainer(config)
trainer.train()
trainer.plot_loss_curve()
# Out:
# 🚀 Starting Training...
# BigVGAN NSynth Dataset: 814 files
# ⏳ Loading BigVGAN (Universal 22kHz)...
# Loading weights from nvidia/bigvgan_v2_22khz_80band_fmax8k_256x
# Removing weight norm...
# ✅ BigVGAN Loaded.
# Trainer Initialized on cuda
# Classes: {'string': 0}
# Model will handle 2 embeddings (Index 1 is NULL)
# Epoch 1/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.1807
# Epoch 2/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0012
# Epoch 3/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9986
# Epoch 4/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0003
# Epoch 5/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0000
# Epoch 6/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0005
# Epoch 7/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0001
# Epoch 8/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0001
# Epoch 9/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9994
# Epoch 10/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9998
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_9.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_9.png
# Epoch 11/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0007
# Epoch 12/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9998
# Epoch 13/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9997
# Epoch 14/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0002
# Epoch 15/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0003
# Epoch 16/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9996
# Epoch 17/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0004
# Epoch 18/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0004
# Epoch 19/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0002
# Epoch 20/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9996
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_19.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_19.png
# Epoch 21/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0009
# Epoch 22/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9993
# Epoch 23/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0000
# Epoch 24/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0004
# Epoch 25/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0006
# Epoch 26/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9987
# Epoch 27/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9999
# Epoch 28/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0001
# Epoch 29/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0001
# Epoch 30/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9989
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_29.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_29.png
# Epoch 31/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0006
# Epoch 32/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9998
# Epoch 33/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9991
# Epoch 34/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0010
# Epoch 35/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9989
# Epoch 36/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9999
# Epoch 37/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0002
# Epoch 38/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0015
# Epoch 39/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0005
# Epoch 40/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0003
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_39.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_39.png
# Epoch 41/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9995
# Epoch 42/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9983
# Epoch 43/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0005
# Epoch 44/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0003
# Epoch 45/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9995
# Epoch 46/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0006
# Epoch 47/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0016
# Epoch 48/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0000
# Epoch 49/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 0.9993
# Epoch 50/50
#   0%|          | 0/26 [00:00<?, ?it/s]
# Average Epoch Loss: 1.0006
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_49.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_49.png
# Saved loss graph to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/loss_curve.png

# %%
import IPython.display as ipd
from src.generator import DiffusionGenerator


ckpt_path = out_dir / 'checkpoint_epoch_49.pt'
gen = DiffusionGenerator(config, ckpt_path)

audio_results = gen.generate(samples_per_class=3) 

# 3. Listen!
print("\n🎧 --- Listening Room ---")
for instrument, waveforms in audio_results.items():
    print(f"\n🎸 Instrument: {instrument}")
    for i, wav in enumerate(waveforms):
        # wav is [1, T], ipd expects [T] numpy array
        audio_data = wav.squeeze().numpy()
        
        # Display Audio Widget
        ipd.display(ipd.Audio(audio_data, rate=22050))
# Out:
# ⏳ Initializing Generator on cuda...
# ⏳ Loading BigVGAN (Universal 22kHz)...
# Loading weights from nvidia/bigvgan_v2_22khz_80band_fmax8k_256x
# Removing weight norm...
# ✅ BigVGAN Loaded.
#    Loaded weights from /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_49.pt
# ✅ Generator Ready.
# 🎹 Generating 3 samples per class...
# 📂 Output: /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated
# Gen: string:   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/string_1.wav
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/string_2.wav
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/string_3.wav
# ✨ Generation Complete!
#
# 🎧 --- Listening Room ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 12
#      10 # 3. Listen!
#      11 print("\n🎧 --- Listening Room ---")
# ---> 12 for instrument, waveforms in audio_results.items():
#      13     print(f"\n🎸 Instrument: {instrument}")
#      14     for i, wav in enumerate(waveforms):
#      15         # wav is [1, T], ipd expects [T] numpy array
#
# AttributeError: 'NoneType' object has no attribute 'items'
