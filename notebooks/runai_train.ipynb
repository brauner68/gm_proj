# %% [markdown]
# # Config + Train

# %%
from src.trainer import DiffusionTrainer
from src.config import get_config
from pathlib import Path

home = Path.home() / 'gm_proj'
data_path = home / 'data/nsynth_data/nsynth-valid'
out_dir = home / 'results/runai_results/01'

# 1. Configuration
config = get_config()
config['output_dir'] = out_dir
config['data_path'] = data_path
config['lr'] = 1e-4
config['max_samples'] = None
config['selected_families'] = ['string', 'mallet']
config['batch_size'] = 32
config['epochs'] = 100
config['save_interval'] = 20
config['cfg_prob'] = 0.1
config['T_target'] = 80

# 2. Run
print("🚀 Starting Training...")
trainer = DiffusionTrainer(config)
trainer.train()
trainer.plot_loss_curve()
# Out:
# 🚀 Starting Training...
# BigVGAN NSynth Dataset: 1477 files
# ⏳ Loading BigVGAN (Universal 22kHz)...
# Loading weights from nvidia/bigvgan_v2_22khz_80band_fmax8k_256x
# Removing weight norm...
# ✅ BigVGAN Loaded.
# Trainer Initialized on cuda
# Classes: {'string': 0, 'mallet': 1}
# Model will handle 3 embeddings (Index 2 is NULL)
# Epoch 1/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdf1bffb240>Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdf1bffb240>Traceback (most recent call last):
#
#   File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1654, in __del__
# Traceback (most recent call last):
#   File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1654, in __del__
#     self._shutdown_workers()
# self._shutdown_workers()  File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#
#       File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
# if w.is_alive():
#      if w.is_alive():
#           ^ ^ ^^^^^^^^^^^^^^^^^^^^^
# ^  File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#
#       File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#                     ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdf1bffb240>Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdf1bffb240>Traceback (most recent call last):
#   File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1654, in __del__
#
# Traceback (most recent call last):
#       File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1654, in __del__
# self._shutdown_workers()
# self._shutdown_workers()  File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#
#       File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
# if w.is_alive():
# if w.is_alive():
#             ^ ^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#   File "/gpfs0/bgu-br/users/nitaype/env/gm-proj/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
# Average Epoch Loss: 0.2708
# Epoch 2/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1460
# Epoch 3/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1277
# Epoch 4/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1208
# Epoch 5/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1202
# Epoch 6/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1070
# Epoch 7/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1116
# Epoch 8/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1034
# Epoch 9/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1038
# Epoch 10/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1080
# Epoch 11/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1090
# Epoch 12/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1084
# Epoch 13/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0996
# Epoch 14/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1071
# Epoch 15/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1024
# Epoch 16/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0956
# Epoch 17/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1046
# Epoch 18/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0989
# Epoch 19/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0944
# Epoch 20/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0938
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_19.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_19.png
# Epoch 21/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0994
# Epoch 22/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1003
# Epoch 23/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0945
# Epoch 24/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1009
# Epoch 25/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0973
# Epoch 26/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0898
# Epoch 27/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0941
# Epoch 28/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0952
# Epoch 29/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1000
# Epoch 30/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0906
# Epoch 31/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1007
# Epoch 32/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0923
# Epoch 33/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0887
# Epoch 34/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0924
# Epoch 35/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1010
# Epoch 36/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0904
# Epoch 37/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1083
# Epoch 38/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0952
# Epoch 39/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0959
# Epoch 40/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0876
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_39.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_39.png
# Epoch 41/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1019
# Epoch 42/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0935
# Epoch 43/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0874
# Epoch 44/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0923
# Epoch 45/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0872
# Epoch 46/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0862
# Epoch 47/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0876
# Epoch 48/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0823
# Epoch 49/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0909
# Epoch 50/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0983
# Epoch 51/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0949
# Epoch 52/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0984
# Epoch 53/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0939
# Epoch 54/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0899
# Epoch 55/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0899
# Epoch 56/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0913
# Epoch 57/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0890
# Epoch 58/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0986
# Epoch 59/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0949
# Epoch 60/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0892
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_59.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_59.png
# Epoch 61/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0939
# Epoch 62/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0900
# Epoch 63/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0899
# Epoch 64/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0918
# Epoch 65/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0832
# Epoch 66/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0971
# Epoch 67/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0901
# Epoch 68/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0883
# Epoch 69/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0909
# Epoch 70/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.1024
# Epoch 71/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0940
# Epoch 72/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0923
# Epoch 73/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0900
# Epoch 74/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0886
# Epoch 75/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0944
# Epoch 76/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0959
# Epoch 77/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0840
# Epoch 78/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0866
# Epoch 79/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0898
# Epoch 80/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0795
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_79.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_79.png
# Epoch 81/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0910
# Epoch 82/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0898
# Epoch 83/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0835
# Epoch 84/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0799
# Epoch 85/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0887
# Epoch 86/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0869
# Epoch 87/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0897
# Epoch 88/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0870
# Epoch 89/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0890
# Epoch 90/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0973
# Epoch 91/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0901
# Epoch 92/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0797
# Epoch 93/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0967
# Epoch 94/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0943
# Epoch 95/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0837
# Epoch 96/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0876
# Epoch 97/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0855
# Epoch 98/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0919
# Epoch 99/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0862
# Epoch 100/100
#   0%|          | 0/47 [00:00<?, ?it/s]
# Average Epoch Loss: 0.0890
# Saved model to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_99.pt
# Generating Validation Samples...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved validation plot to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/sample_epoch_99.png
# Saved loss graph to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/loss_curve.png

# %%
import IPython.display as ipd
from src.generator import DiffusionGenerator


ckpt_path = out_dir / 'checkpoint_epoch_39.pt'
gen = DiffusionGenerator(config, ckpt_path)

audio_results = gen.generate(samples_per_class=2) 

# 3. Listen!
print("\n🎧 --- Listening Room ---")
for instrument, waveforms in audio_results.items():
    print(f"\n🎸 Instrument: {instrument}")
    for i, wav in enumerate(waveforms):
        # wav is [1, T], ipd expects [T] numpy array
        audio_data = wav.squeeze().numpy()
        
        # Display Audio Widget
        ipd.display(ipd.Audio(audio_data, rate=22050))
# Out:
# ⏳ Initializing Generator on cuda...
# ⏳ Loading BigVGAN (Universal 22kHz)...
# Loading weights from nvidia/bigvgan_v2_22khz_80band_fmax8k_256x
# Removing weight norm...
# ✅ BigVGAN Loaded.
#    Loaded weights from /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/checkpoint_epoch_39.pt
# ✅ Generator Ready.
# 🎹 Generating 2 samples per class...
# 📂 Output: /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated
# Gen: string:   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/string_1.wav
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/string_2.wav
# Gen: mallet:   0%|          | 0/1000 [00:00<?, ?it/s]
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/mallet_1.wav
# Saved audio to /gpfs0/bgu-br/users/nitaype/gm_proj/results/runai_results/01/generated/mallet_2.wav
# ✨ Generation Complete!
#
# 🎧 --- Listening Room ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 12
#      10 # 3. Listen!
#      11 print("\n🎧 --- Listening Room ---")
# ---> 12 for instrument, waveforms in audio_results.items():
#      13     print(f"\n🎸 Instrument: {instrument}")
#      14     for i, wav in enumerate(waveforms):
#      15         # wav is [1, T], ipd expects [T] numpy array
#
# AttributeError: 'NoneType' object has no attribute 'items'
